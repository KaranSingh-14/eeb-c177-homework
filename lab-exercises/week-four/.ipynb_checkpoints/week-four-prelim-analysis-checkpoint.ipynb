# %%
import pandas as pd
tmp_data = pd.read_csv('Karan_Dataset.csv')
data = tmp_data.to_numpy()

# %%
df = pd.DataFrame(tmp_data, columns = ['Transect', 'species', 'count', 'prob.', 'A. herba-alba Expected coex.', 'A. herba-alba Real coex.', 'L. spartum Expected coex.', 'L. spartum Real coex.', 'S. vermiculata Expected coex.', 'S. vermiculata Real coex.' ])
df
# Out:
#      Transect   species  count     prob.  A. herba-alba Expected coex.  \
# 0           1    allium      1  0.000800                        0.0768
# 1           1  anacyclu      1  0.000800                        0.0768
# 2           1     anaga      1  0.000800                        0.0768
# 3           1    ARTIBA     96  0.076800                           NaN
# 4           1      ASPH      9  0.007200                        0.6912
# ..        ...       ...    ...       ...                           ...
# 312         6  STIPALAG    102  0.081535                       10.8426
# 313         6    STIPAR     23  0.018385                        2.4449
# 314         6    taraxa     13  0.010392                        1.3819
# 315         6    TEUCAP      5  0.003997                        0.5315
# 316         6   THYMUVU     26  0.020783                        2.7638
#
#      A. herba-alba Real coex.  L. spartum Expected coex.  \
# ...

# %%
#I am trying to see the difference between the expected coexistence between two different species.
df = pd.DataFrame(tmp_data, columns = [ 'A. herba-alba Expected coex.', 'A. herba-alba Real coex.'])
df.plot(x= 'A. herba-alba Expected coex.', y = 'A. herba-alba Real coex.', kind = 'scatter' )

# %%
#I am trying to see the difference between the real coexistence between two different species.
df = pd.DataFrame(tmp_data, columns = [ 'A. herba-alba Real coex.', 'L. spartum Real coex.'])
df.plot(x= 'A. herba-alba Real coex.', y = 'L. spartum Real coex.', kind = 'scatter' )

# %%
#I am trying to see the difference between the real coexistence between two different species.
df = pd.DataFrame(tmp_data, columns = [ 'A. herba-alba Real coex.', 'S. vermiculata Real coex.'])
df.plot(x= 'A. herba-alba Real coex.', y = 'S. vermiculata Real coex.', kind = 'scatter' )

# %%
#I am trying to see the difference between the expected coexistence between two different species.
df = pd.DataFrame(tmp_data, columns = [ 'A. herba-alba Expected coex.', 'S. vermiculata Expected coex.'])
df.plot(x= 'A. herba-alba Expected coex.', y = 'S. vermiculata Expected coex.', kind = 'line' )

# %%
#I am trying to see the difference between the expected and real coexistence amongst the same species.
df = pd.DataFrame(tmp_data, columns = [ 'S. vermiculata Expected coex.', 'S. vermiculata Real coex.'])
df.plot(x= 'S. vermiculata Expected coex.', y = 'S. vermiculata Real coex.', kind = 'scatter' )

# %%
df = pd.DataFrame(tmp_data, columns = [ 'S. vermiculata Real coex.', 'A. herba-alba Real coex.'])
df.plot(x= 'S. vermiculata Real coex.', y = 'A. herba-alba Real coex.', kind = 'scatter' )

# %%
df = pd.DataFrame(tmp_data, columns = [ 'count', 'A. herba-alba Real coex.'])
df.plot(x= 'count', y = 'A. herba-alba Real coex.', kind = 'scatter' )

# %%
#I want to see how the count coorelates to real coexistence
df = pd.DataFrame(tmp_data, columns = [ 'count', 'L. spartum Real coex.'])
df.plot(x= 'count', y = 'L. spartum Real coex.', kind = 'scatter' )

# %%
#I want to see how the count coorelates to expected coexistence
df = pd.DataFrame(tmp_data, columns = [ 'count', 'L. spartum Expected coex.'])
df.plot(x= 'count', y = 'L. spartum Expected coex.', kind = 'scatter' )

# %%
#I want to see how the count coorelates to real coexistence
df = pd.DataFrame(tmp_data, columns = [ 'count', 'S. vermiculata Real coex.'])
df.plot(x= 'count', y = 'S. vermiculata Real coex.', kind = 'scatter' )

# %%
#I want to see how the count coorelates to expected coexistence
df = pd.DataFrame(tmp_data, columns = [ 'count', 'S. vermiculata Expected coex.'])
df.plot(x= 'count', y = 'S. vermiculata Expected coex.', kind = 'scatter' )

# %%
df = pd.DataFrame(tmp_data, columns = [ 'prob.', 'S. vermiculata Expected coex.'])
df.plot(x= 'prob.', y = 'S. vermiculata Expected coex.', kind = 'scatter' )

# %%
#I wanted to see the relationship between count and the probability of coexistence
df = pd.DataFrame(tmp_data, columns = [ 'prob.', 'count'])
df.plot(x= 'prob.', y = 'count', kind = 'scatter' )
