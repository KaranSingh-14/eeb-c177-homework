# %%
import numpy as np
data = np.loadtxt(fname='../week-four/inflammation-01.csv', delimiter=',')
print(data)
# Out:
# [[0. 0. 1. ... 3. 0. 0.]
#  [0. 1. 2. ... 1. 0. 1.]
#  [0. 1. 1. ... 2. 1. 1.]
#  ...
#  [0. 0. 1. ... 3. 0. 0.]
#  [0. 1. 2. ... 1. 0. 1.]
#  [0. 1. 1. ... 2. 1. 1.]]

# %%
import matplotlib.pyplot as plt

# %%
ave_inflammation = np.mean(data, axis=0)
ave_plot = plt.plot(ave_inflammation)
plt.xlabel('time in days')
plt.ylabel('patient inflammation score')
plt.title('patient data')
plt.show()

# %%
fig = plt.figure(figsize=(10.0, 10.0))

fig.suptitle('Patient Scores', va='bottom', fontsize=16)

sbplot1 = fig.add_subplot(3, 1, 1)
sbplot2 = fig.add_subplot(3,1,2)
sbplot3 = fig.add_subplot(3,1,3)

sbplot1.set_ylabel('average')
sbplot1.plot(np.mean(data, axis=0), '--')

sbplot2.set_xlabel('Time (days)')
sbplot2.set_ylabel('max')
sbplot2.plot(np.max(data, axis=0), '-o')

sbplot3.set_ylabel('min')
sbplot3.plot(np.min(data, axis=0), '-*')


fig.tight_layout()

plt.show()

# %%
#Part 2

# %%
#Part 3
#1 List is a collection which is ordered and changeable. Allows duplicate members.
#2 You access the list items by referring to the index number. For example thislist = ["karan", "k"]
#You can specify a range of indexes by specifying where to start and where to end the range. When specifying a range, the return value will be a new list with the specified items.
#3 You can change values of elements by changing the key in the listed dictionary code. Append or Change Single Element of Dictionary With Python By using the update() function of Python, you can add or change the single key value of Dictionary 
#4 YOu can update it via the append function and add to our current dictionary. You can also use the pop command and it will remove whatever key you want to remove.

# %%
#5
h = "hello"
list(h)
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
#6
string_for_slicing = "Observation date: 02-Feb-2013"
list_for_slicing = [["fluorine", "F"],
                 ["chlorine", "Cl"],
                 ["bromine", "Br"],
                 ["iodine", "I"],
                 ["astatine", "At"]]
print('last 4 char:', string_for_slicing[-4:])
print('last 4 entities:', list_for_slicing[-4:])
# Out:
# last 4 char: 2013
# last 4 entities: [['chlorine', 'Cl'], ['bromine', 'Br'], ['iodine', 'I'], ['astatine', 'At']]

# %%
#7
# I extracted [-4:] which means it will extract last four chars or entities of any object.

# %%
#Part 4

# %%
#1 
#Since 4 is less than 5 it will print c
if 4 > 5:
 print('A')
elif 4 == 5:
 print('B')
elif 4 < 5:
 print('C')
# Out:
# C

# %%
#2 
sentence = input("Type sentence here: ")
Number_counter = {b:0 for b in 'aeiouOUIEA'}
for bb in sentence:
    if bb in Number_counter:
        Number_counter[bb]+= 1
print(sum(Number_counter.values()))
# Out:
# Type sentence here: Karan
# 2

# %%
sentence = input("Type sentence here: ")
Number_counter = {b:0 for b in 'aeiouOUIEA'}
for bb in sentence:
    if bb in Number_counter:
        Number_counter[bb]+= 1
print(sum(Number_counter.values()))
# Out:
# Type sentence here: Karan Singh is tall
# 5

# %%
sentence = input("Type sentence here: ")
Number_counter = {b:0 for b in 'aeiouOUIEA'}
for bb in sentence:
    if bb in Number_counter:
        Number_counter[bb]+= 1
print(sum(Number_counter.values()))
# Out:
# Type sentence here: I am a basketball player
# 8

# %%
sentence = input("Type sentence here: ")
Number_counter = {b:0 for b in 'aeiouOUIEA'}
for bb in sentence:
    if bb in Number_counter:
        Number_counter[bb]+= 1
print(sum(Number_counter.values()))
# Out:
# Type sentence here: Kobe Bryant
# 3

# %%
#3 Extra Credit


for i in range(0,5):
    for j in range(0,5-i-1):
        print(end=" ")
    for j in range(0,i+1):
        print("*", end=" ")
    print()
# Out:
#     *
#    * *
#   * * *
#  * * * *
# * * * * *
